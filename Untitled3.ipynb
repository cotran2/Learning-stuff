# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv(r'D:\Documents\ML\Pokemon.csv')
print(data.head(5))
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.columns = data.columns.str.upper().str.replace('_', '')
data[data['LEGENDARY']==True].head(5)
data = data.set_index('NAME')

# %%
data.index = data.index.str.replace(".*(?=Mega)", "")
data.head(5)
# Out:
#                # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  \
# NAME
# Bulbasaur      1  Grass  Poison    318  45      49       49       65       65
# Ivysaur        2  Grass  Poison    405  60      62       63       80       80
# Venusaur       3  Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  3  Grass  Poison    625  80     100      123      122      120
# Charmander     4   Fire     NaN    309  39      52       43       60       50
#
#                SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur         45           1      False
# Ivysaur           60           1      False
# Venusaur          80           1      False
# Mega Venusaur     80           1      False
# Charmander        65           1      False

# %%
data.drop(['#'],axis=1)
# Out:
#                          TYPE 1  TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur                 Grass  Poison    318   45      49       49       65
# Ivysaur                   Grass  Poison    405   60      62       63       80
# Venusaur                  Grass  Poison    525   80      82       83      100
# Mega Venusaur             Grass  Poison    625   80     100      123      122
# Charmander                 Fire     NaN    309   39      52       43       60
# Charmeleon                 Fire     NaN    405   58      64       58       80
# Charizard                  Fire  Flying    534   78      84       78      109
# Mega Charizard X           Fire  Dragon    634   78     130      111      130
# Mega Charizard Y           Fire  Flying    634   78     104       78      159
# Squirtle                  Water     NaN    314   44      48       65       50
# Wartortle                 Water     NaN    405   59      63       80       65
# ...

# %%
print('The columns of the dataset are',data.columns)
print('The shape of the dataset are',data.shape)
# Out:
# The columns of the dataset are Index(['#', 'TYPE 1', 'TYPE 2', 'TOTAL', 'HP', 'ATTACK', 'DEFENSE', 'SP. ATK',
#        'SP. DEF', 'SPEED', 'GENERATION', 'LEGENDARY'],
#       dtype='object')
# The shape of the dataset are (800, 12)

# %%
data['TYPE 2'].fillna(data['TYPE 1'],inplace = True)

# %%
#print(data.loc['Bulbasaur'])
#print(data.iloc[0])
#print(data.ix[0])
print(data.ix['Kakuna'])
# Out:
# #                 14
# TYPE 1           Bug
# TYPE 2        Poison
# TOTAL            205
# HP                45
# ATTACK            25
# DEFENSE           50
# SP. ATK           25
# SP. DEF           25
# SPEED             35
# GENERATION         1
# LEGENDARY      False
# Name: Kakuna, dtype: object

# %%
print('Max HP:',data['HP'].argmax())
print('Max Defense:',data['DEFENSE'].argmax())
# Out:
# Max HP: Blissey
# Max Defense: Mega Steelix

# %%
a = np.arrange(36)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-e548edbaebfa> in <module>()
# ----> 1 a = np.arrange(36)
#
# AttributeError: module 'numpy' has no attribute 'arrange'
